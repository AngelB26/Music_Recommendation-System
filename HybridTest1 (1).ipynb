# %%
import pandas as pd
import numpy as np
import Recommenders as Recommenders

# %%
song_df_1 = pd.read_csv('triplets_file.csv')
song_df_1.head()
# Out:
#                                     user_id             song_id  listen_count
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1

# %%
song_df_2 = pd.read_csv('song_data.csv')
song_df_2.head()
# Out:
#               song_id              title  \
# 0  SOQMMHC12AB0180CB8       Silent Night
# 1  SOVFVAK12A8C1350D9        Tanssi vaan
# 2  SOGTUKN12AB017F4F1  No One Could Ever
# 3  SOBNYVR12A8C13558C      Si Vos Querés
# 4  SOHSBXH12A8C13B0DF   Tangle Of Aspens
#
#                                 release       artist_name  year
# 0                 Monster Ballads X-Mas  Faster Pussy cat  2003
# 1                           Karkuteillä  Karkkiautomaatti  1995
# 2                                Butter    Hudson Mohawke  2006
# 3                               De Culo       Yerba Brava  2003
# 4  Rene Ablaze Presents Winter Sessions        Der Mystic     0

# %%
# combine both data
song_df = pd.merge(song_df_1, song_df_2.drop_duplicates(['song_id']), on='song_id', how='left')
song_df.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1
#
#              title                        release    artist_name  year
# 0         The Cove             Thicker Than Water   Jack Johnson     0
# 1  Entre Dos Aguas            Flamenco Para Niños  Paco De Lucia  1976
# 2         Stronger                     Graduation     Kanye West  2007
# 3   Constellations              In Between Dreams   Jack Johnson  2005
# 4     Learn To Fly  There Is Nothing Left To Lose   Foo Fighters  1999

# %%
print(len(song_df_1), len(song_df_2))
# Out:
# 2000000 1000000

# %%
song_df.shape
# Out:
# (2000000, 7)

# %%
# creating new feature combining title and artist name
song_df['song'] = song_df['title']+' - '+song_df['artist_name']
song_df.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1
#
#              title                        release    artist_name  year  \
# 0         The Cove             Thicker Than Water   Jack Johnson     0
# 1  Entre Dos Aguas            Flamenco Para Niños  Paco De Lucia  1976
# 2         Stronger                     Graduation     Kanye West  2007
# 3   Constellations              In Between Dreams   Jack Johnson  2005
# 4     Learn To Fly  There Is Nothing Left To Lose   Foo Fighters  1999
#
#                               song
# 0          The Cove - Jack Johnson
# 1  Entre Dos Aguas - Paco De Lucia
# 2            Stronger - Kanye West
# 3    Constellations - Jack Johnson
# 4      Learn To Fly - Foo Fighters

# %%
# taking top 10k samples for quick results
song_df = song_df.head(10000)

# %%
# cummulative sum of listen count of the songs
song_grouped = song_df.groupby(['song']).agg({'listen_count':'count'}).reset_index()
song_grouped.head()
# Out:
#                                     song  listen_count
# 0               #40 - DAVE MATTHEWS BAND             1
# 1                    & Down - Boys Noize             4
# 2            '97 Bonnie & Clyde - Eminem             2
# 3          'Round Midnight - Miles Davis             3
# 4  'Till I Collapse - Eminem / Nate Dogg             6

# %%
#Finding avg
grouped_sum = song_grouped['listen_count'].sum()
song_grouped['percentage'] = (song_grouped['listen_count'] / grouped_sum ) * 100
song_grouped.sort_values(['listen_count', 'song'], ascending=[0,1])
# Out:
#                                                    song  listen_count  \
# 3660                           Sehr kosmisch - Harmonia            45
# 4678                                       Undo - Björk            32
# 5105                     You're The One - Dwight Yoakam            32
# 1071  Dog Days Are Over (Radio Edit) - Florence + Th...            28
# 3655                              Secrets - OneRepublic            28
# ...                                                 ...           ...
# 5139                              high fives - Four Tet             1
# 5140                       in white rooms - Booka Shade             1
# 5143             paranoid android - Christopher O'Riley             1
# 5149            ¿Lo Ves? [Piano Y Voz] - Alejandro Sanz             1
# 5150                              Época - Gotan Project             1
#
#       percentage
# 3660        0.45
# 4678        0.32
# 5105        0.32
# 1071        0.28
# 3655        0.28
# ...          ...
# 5139        0.01
# 5140        0.01
# 5143        0.01
# 5149        0.01
# 5150        0.01
#
# [5151 rows x 3 columns]

# %%
pr = Recommenders.popularity_recommender_py()

# %%
pr.create(song_df, 'user_id', 'song')

# %%
# display the top 10 popular songs
pr.recommend(song_df['user_id'][10])
# Out:
#                                        user_id  \
# 3660  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 4678  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 5105  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 1071  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 3655  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 4378  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 4712  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 3476  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 1387  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 1862  b80344d063b5ccb3212f76538f3d9e43d87dca9e
#
#                                                    song  score  Rank
# 3660                           Sehr kosmisch - Harmonia     45   1.0
# 4678                                       Undo - Björk     32   2.0
# 5105                     You're The One - Dwight Yoakam     32   3.0
# 1071  Dog Days Are Over (Radio Edit) - Florence + Th...     28   4.0
# 3655                              Secrets - OneRepublic     28   5.0
# 4378                           The Scientist - Coldplay     27   6.0
# 4712                       Use Somebody - Kings Of Leon     27   7.0
# 3476                            Revelry - Kings Of Leon     26   8.0
# 1387                     Fireflies - Charttraxx Karaoke     24   9.0
# 1862  Horn Concerto No. 4 in E flat K495: II. Romanc...     23  10.0

# %%
pr.recommend(song_df['user_id'][100])
# Out:
#                                        user_id  \
# 3660  e006b1a48f466bf59feefed32bec6494495a4436
# 4678  e006b1a48f466bf59feefed32bec6494495a4436
# 5105  e006b1a48f466bf59feefed32bec6494495a4436
# 1071  e006b1a48f466bf59feefed32bec6494495a4436
# 3655  e006b1a48f466bf59feefed32bec6494495a4436
# 4378  e006b1a48f466bf59feefed32bec6494495a4436
# 4712  e006b1a48f466bf59feefed32bec6494495a4436
# 3476  e006b1a48f466bf59feefed32bec6494495a4436
# 1387  e006b1a48f466bf59feefed32bec6494495a4436
# 1862  e006b1a48f466bf59feefed32bec6494495a4436
#
#                                                    song  score  Rank
# 3660                           Sehr kosmisch - Harmonia     45   1.0
# 4678                                       Undo - Björk     32   2.0
# 5105                     You're The One - Dwight Yoakam     32   3.0
# 1071  Dog Days Are Over (Radio Edit) - Florence + Th...     28   4.0
# 3655                              Secrets - OneRepublic     28   5.0
# 4378                           The Scientist - Coldplay     27   6.0
# 4712                       Use Somebody - Kings Of Leon     27   7.0
# 3476                            Revelry - Kings Of Leon     26   8.0
# 1387                     Fireflies - Charttraxx Karaoke     24   9.0
# 1862  Horn Concerto No. 4 in E flat K495: II. Romanc...     23  10.0

# %%
ir = Recommenders.item_similarity_recommender_py()
ir.create(song_df, 'user_id', 'song')

# %%
user_items = ir.get_user_items(song_df['user_id'][110])

# %%
# display user songs history
for user_item in user_items:
    print(user_item)
# Out:
# Undo - Björk
# Dog Days Are Over (Radio Edit) - Florence + The Machine
# High Life - Daft Punk
# You're The One - Dwight Yoakam
# Where Did You Sleep Last Night - Nirvana
# Come As You Are - Nirvana
# Hey_ Soul Sister - Train
# Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile) - Barry Tuckwell/Academy of St Martin-in-the-Fields/Sir Neville Marriner
# Rhyme & Reason - DAVE MATTHEWS BAND
# Sehr kosmisch - Harmonia
# Someone Else's Arms - Mae
# Cry For Help (Album Version) - Shinedown
# Lady In Black - Ensiferum
# For You (Amended/Radio Edit LP) - Staind
# Fireflies - Charttraxx Karaoke
# Secrets - OneRepublic
# Esta Es Para Hacerte Féliz - Jorge Gonzalez
# Revelry - Kings Of Leon
# Marry Me - Train
# OMG - Usher featuring will.i.am
# Drop The World - Lil Wayne / Eminem
# Ain't Misbehavin - Sam Cooke
# Blow Me Away - Breaking Benjamin
# Use Somebody - Kings Of Leon
# Corn Bread - DAVE MATTHEWS BAND

# %%
# give song recommendation for that user
inputContent = ir.recommend(song_df['user_id'][5])
inputContent
# Out:
# No. of unique songs for the user: 45
# no. of unique songs in the training set: 5151
# Non zero values in cooccurence_matrix :6844
#                                     user_id  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 5  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 6  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 7  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 8  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 9  b80344d063b5ccb3212f76538f3d9e43d87dca9e
#
#                                         song     score  rank
# 0                 Oliver James - Fleet Foxes  0.043076     1
# 1                 Quiet Houses - Fleet Foxes  0.043076     2
# 2               Your Protector - Fleet Foxes  0.043076     3
# 3  Tiger Mountain Peasant Song - Fleet Foxes  0.043076     4
# 4                 Sun It Rises - Fleet Foxes  0.043076     5
# 5                        The End - Pearl Jam  0.037531     6
# 6                St. Elsewhere - Dave Grusin  0.037531     7
# 7                       Misled - Céline Dion  0.037531     8
# 8                    Oil And Water - Incubus  0.037531     9
# 9                  Meadowlarks - Fleet Foxes  0.037531    10

# %%
inputContent.shape
# Out:
# (10, 4)

# %%
from skimage import io
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime


from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics.pairwise import cosine_similarity

# %%
data1 = pd.read_csv('data.csv')
data1.head()
# Out:
#    valence  year  acousticness  \
# 0   0.0594  1921         0.982
# 1   0.9630  1921         0.732
# 2   0.0394  1921         0.961
# 3   0.1650  1921         0.967
# 4   0.2530  1921         0.957
#
#                                              artists  danceability  \
# 0  ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                     ['Dennis Day']         0.819
# 2  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                   ['Frank Parker']         0.275
# 4                                     ['Phil Regan']         0.418
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz          0.878000
# 1       180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8          0.000000
# 2       500062   0.166         0  1o6I8BglA6ylDMrIELygv1          0.913000
# 3       210000   0.309         0  3ftBPsC5vPBKxYSee08FDH          0.000028
# 4       166693   0.193         0  4d6HGyGT8e121BsdKmw9v6          0.000002
#
#    key  liveness  loudness  mode  \
# 0   10     0.665   -20.096     1
# 1    7     0.160   -12.441     1
# 2    3     0.101   -14.850     1
# 3    5     0.381    -9.316     1
# 4    3     0.229   -10.096     1
#
#                                                 name  popularity release_date  \
# 0  Piano Concerto No. 3 in D Minor, Op. 30: III. ...           4         1921
# 1                            Clancy Lowered the Boom           5         1921
# 2                                          Gati Bali           5         1921
# 3                                          Danny Boy           3         1921
# 4                        When Irish Eyes Are Smiling           2         1921
#
#    speechiness    tempo
# 0       0.0366   80.954
# 1       0.4150   60.936
# 2       0.0339  110.339
# 3       0.0354  100.109
# 4       0.0380  101.665

# %%
features_df = data1

# %%
scaled_features = MinMaxScaler().fit_transform([
features_df['valence'].values,
features_df['acousticness'].values,
features_df['duration_ms'].values,
features_df['energy'].values,
features_df['liveness'].values,
features_df['speechiness'].values,
features_df['loudness'].values,
features_df['key'].values,
features_df['tempo'].values,
features_df['instrumentalness'],
features_df['explicit'],
features_df['danceability'],
  ])

# %%
features_df[['key','acousticness','danceability','duration_ms','energy','explicit','instrumentalness','liveness','loudness','speechiness','tempo','valence']] = scaled_features.T

# %%
# features_df = features_df.drop('ArtistName', axis = 1)
# features_df = features_df.drop('Title',axis = 1)
features_df = features_df.drop('year', axis = 1)
features_df = features_df.drop('mode', axis = 1)
features_df = features_df.drop('popularity', axis = 1)
features_df = features_df.drop('release_date', axis = 1)

# %%
features_df.head()
# Out:
#     valence  acousticness                                            artists  \
# 0  0.000024      0.000025  ['Sergei Rachmaninoff', 'James Levine', 'Berli...
# 1  0.000073      0.000073                                     ['Dennis Day']
# 2  0.000030      0.000032  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...
# 3  0.000046      0.000049                                   ['Frank Parker']
# 4  0.000063      0.000066                                     ['Phil Regan']
#
#    danceability  duration_ms    energy  explicit                      id  \
# 0           1.0     0.000024  0.000025  0.000024  4BJqT0PrAfrxzMOxytFOIz
# 1           1.0     0.000071  0.000070  0.000071  7xPhfUan2yNtyFG0cUWkt8
# 2           1.0     0.000030  0.000030  0.000030  1o6I8BglA6ylDMrIELygv1
# 3           1.0     0.000046  0.000046  0.000045  3ftBPsC5vPBKxYSee08FDH
# 4           1.0     0.000062  0.000062  0.000061  4d6HGyGT8e121BsdKmw9v6
#
#    instrumentalness       key  liveness  loudness  \
# 0               0.0  0.000024  0.000036  0.000122
# 1               0.0  0.000074  0.000108  0.000406
# 2               0.0  0.000030  0.000036  0.000250
# 3               0.0  0.000045  0.000068  0.000521
# 4               0.0  0.000062  0.000079  0.000670
#
#                                                 name  speechiness     tempo
# 0  Piano Concerto No. 3 in D Minor, Op. 30: III. ...     0.000025  0.000024
# 1                            Clancy Lowered the Boom     0.000069  0.000069
# 2                                          Gati Bali     0.000032  0.000030
# 3                                          Danny Boy     0.000044  0.000044
# 4                        When Irish Eyes Are Smiling     0.000061  0.000061

# %%
features_df['artists'] = features_df['artists'].str.replace('[', '',regex=True)
features_df['artists'] = features_df['artists'].str.replace(']', '',regex=True)
features_df['artists'] = features_df['artists'].str.replace('\'', '',regex=True)

# %%
features_df['song'] = features_df['name']+' - '+features_df['artists']
features_df.head()
# Out:
#     valence  acousticness                                            artists  \
# 0  0.000024      0.000025  Sergei Rachmaninoff, James Levine, Berliner Ph...
# 1  0.000073      0.000073                                         Dennis Day
# 2  0.000030      0.000032  KHP Kridhamardawa Karaton Ngayogyakarta Hadini...
# 3  0.000046      0.000049                                       Frank Parker
# 4  0.000063      0.000066                                         Phil Regan
#
#    danceability  duration_ms    energy  explicit                      id  \
# 0           1.0     0.000024  0.000025  0.000024  4BJqT0PrAfrxzMOxytFOIz
# 1           1.0     0.000071  0.000070  0.000071  7xPhfUan2yNtyFG0cUWkt8
# 2           1.0     0.000030  0.000030  0.000030  1o6I8BglA6ylDMrIELygv1
# 3           1.0     0.000046  0.000046  0.000045  3ftBPsC5vPBKxYSee08FDH
# 4           1.0     0.000062  0.000062  0.000061  4d6HGyGT8e121BsdKmw9v6
#
#    instrumentalness       key  liveness  loudness  \
# 0               0.0  0.000024  0.000036  0.000122
# 1               0.0  0.000074  0.000108  0.000406
# 2               0.0  0.000030  0.000036  0.000250
# 3               0.0  0.000045  0.000068  0.000521
# 4               0.0  0.000062  0.000079  0.000670
#
#                                                 name  speechiness     tempo  \
# 0  Piano Concerto No. 3 in D Minor, Op. 30: III. ...     0.000025  0.000024
# 1                            Clancy Lowered the Boom     0.000069  0.000069
# 2                                          Gati Bali     0.000032  0.000030
# 3                                          Danny Boy     0.000044  0.000044
# 4                        When Irish Eyes Are Smiling     0.000061  0.000061
#
#                                                 song
# 0  Piano Concerto No. 3 in D Minor, Op. 30: III. ...
# 1               Clancy Lowered the Boom - Dennis Day
# 2  Gati Bali - KHP Kridhamardawa Karaton Ngayogya...
# 3                           Danny Boy - Frank Parker
# 4           When Irish Eyes Are Smiling - Phil Regan

# %%
features_df = features_df.drop('artists', axis = 1)
features_df = features_df.drop('name', axis = 1)

# %%
features_df.head()
# Out:
#     valence  acousticness  danceability  duration_ms    energy  explicit  \
# 0  0.000024      0.000025           1.0     0.000024  0.000025  0.000024
# 1  0.000073      0.000073           1.0     0.000071  0.000070  0.000071
# 2  0.000030      0.000032           1.0     0.000030  0.000030  0.000030
# 3  0.000046      0.000049           1.0     0.000046  0.000046  0.000045
# 4  0.000063      0.000066           1.0     0.000062  0.000062  0.000061
#
#                        id  instrumentalness       key  liveness  loudness  \
# 0  4BJqT0PrAfrxzMOxytFOIz               0.0  0.000024  0.000036  0.000122
# 1  7xPhfUan2yNtyFG0cUWkt8               0.0  0.000074  0.000108  0.000406
# 2  1o6I8BglA6ylDMrIELygv1               0.0  0.000030  0.000036  0.000250
# 3  3ftBPsC5vPBKxYSee08FDH               0.0  0.000045  0.000068  0.000521
# 4  4d6HGyGT8e121BsdKmw9v6               0.0  0.000062  0.000079  0.000670
#
#    speechiness     tempo                                               song
# 0     0.000025  0.000024  Piano Concerto No. 3 in D Minor, Op. 30: III. ...
# 1     0.000069  0.000069               Clancy Lowered the Boom - Dennis Day
# 2     0.000032  0.000030  Gati Bali - KHP Kridhamardawa Karaton Ngayogya...
# 3     0.000044  0.000044                           Danny Boy - Frank Parker
# 4     0.000061  0.000061           When Irish Eyes Are Smiling - Phil Regan

# %%
song_df2 = pd.merge(inputContent, features_df.drop_duplicates(['song']), on='song', how='inner')
song_df2.head(10)
# Out:
#                                     user_id  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 5  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 6  b80344d063b5ccb3212f76538f3d9e43d87dca9e
#
#                                         song     score  rank   valence  \
# 0                 Oliver James - Fleet Foxes  0.043076     1  0.000064
# 1                 Quiet Houses - Fleet Foxes  0.043076     2  0.000035
# 2               Your Protector - Fleet Foxes  0.043076     3  0.000036
# 3  Tiger Mountain Peasant Song - Fleet Foxes  0.043076     4  0.000064
# 4                 Sun It Rises - Fleet Foxes  0.043076     5  0.000051
# 5                        The End - Pearl Jam  0.037531     6  0.000060
# 6                  Meadowlarks - Fleet Foxes  0.037531    10  0.000073
#
#    acousticness  danceability  duration_ms    energy  explicit  \
# 0      0.000066           1.0     0.000062  0.000062  0.000062
# 1      0.000033           1.0     0.000036  0.000033  0.000033
# 2      0.000036           1.0     0.000036  0.000034  0.000034
# 3      0.000065           1.0     0.000061  0.000061  0.000061
# 4      0.000051           1.0     0.000049  0.000048  0.000048
# 5      0.000062           1.0     0.000058  0.000057  0.000057
# 6      0.000075           1.0     0.000071  0.000071  0.000071
#
#                        id  instrumentalness       key  liveness  loudness  \
# 0  0ksHQqgNvM8IBmOfXOh5qt               0.0  0.000063  0.000062  0.000644
# 1  4r92wg5khzEKYB4SZ8s82H               0.0  0.000035  0.000084  0.000550
# 2  4fuVAz1Epsftsv71dkGOZY               0.0  0.000035  0.000050  0.000435
# 3  74TdnqQ0JlIcHBwdSAATiw               0.0  0.000062  0.000089  0.000687
# 4  2SDtvOPEVO6NBDXsKcibY2               0.0  0.000048  0.000084  0.000633
# 5  0PkOdIbNj8L3e0p1JGIfLO               0.0  0.000059  0.000091  0.000718
# 6  0bSEOwEDH7D32nkmsTit42               0.0  0.000071  0.000107  0.000623
#
#    speechiness     tempo
# 0     0.000062  0.000062
# 1     0.000035  0.000033
# 2     0.000034  0.000034
# 3     0.000060  0.000060
# 4     0.000048  0.000048
# 5     0.000057  0.000057
# 6     0.000071  0.000070

# %%
song_df2.shape
# Out:
# (7, 17)

# %%
# Out:
# (0, 34)
